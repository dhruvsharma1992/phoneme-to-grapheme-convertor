# %%
with open('german_ipa','r') as german_ipa:
    total_data = german_ipa.read().strip().split("   ")
    with open('german_ipa_out','w') as german_ipa_out:
        ipa_list = []
        for word in total_data:
            ipa_list.append(word)
        german_ipa_out.write()
# Out:
# b ə v ɪ l ɪ g ə n
# f o: r ʃ r ɪ f t
# ɛ r b ɪ t ə r ʊ ŋ
# a n ts u: k
# k ɔ s t ə n
# n ɔʏ g i: r ɪ ç
# aɪ g ə n s t a: t l ɪ ç k aɪ t
# j u: k s
# ʃ r aɪ t ə n
# h ɪ n
# t ɛ m p ɔ
# t r a x t
# f ɛ r ts ɪ n z ə n
# f ɛ s t n a: m ə
# l aɪ ç t
# ʃ v ɪ n d ə n
# r e: n ɔ m i: r t
# ʃ l ɛ n d ɐ n
# v e: r d ə g a ŋ
# m ʊ l d ə
# d ʊ r ç ʃ t e: ə n
# g ə b r aʊ x ə n
# f ɛ r v ɛ l k ə n
# b e: n e: b ə l t
# a x t ʊ ŋ
# a n ʃ t ɛ l ə
# m o: m ɛ n t a: n
# f ɛ r t i: f t
# b ə l e: k t ə
# ʃ p ɔ r t l ɐ
# a n f a l ə n
# f l i: z ə
# g ə z ɛ ts g e: b ɐ
# ʃ v ʊ n t
# f ɛ r z e: ə n t l ɪ ç
# p ʊ l l o: f ɐ
# b r ɛ m z ə n
# p a s i: r ə n
# ʃ p ɛ r ə n
# k r i: ç ə n
# l ɪ ç t tʃ a l t ɐ
# aɪ n d r ɪ ŋ l ɪ ç
# f aɪ n t
# ʃ v ɛ l ts ə n
# b ə ʃ aɪ d ə n
# aɪ t
# a n g ə n e: m
# h a r ə n
# z ɔ g l aɪ ç
# v i: d ɐ ʃ p r ʊ x
# ʊ m b ə n ɛ n ə n
# b a l t
# b ə t r aʊ ə n
# g ə l ɛ ŋ k
# a n d ɐ s v o:
# h ɔ k ɐ
# l e: p ts aɪ t ə n
# ʃ n a r ç ə n
# v ɪ ŋ k
# ʃ aʊ f ɛ n s t ɐ
# r ɛ n ə n
# ...
