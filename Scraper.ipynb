# %%
from bs4 import BeautifulSoup
import requests

# %%
quote_page = "http://www.heardutchhere.net/duengero.html"
page = requests.get(quote_page)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
rows=soup.findAll('table')[2]

# %%
for row in rows.findAll('tr'):
    for row_element in row.findAll('td')[::3]:
        i=0
        for row_elemental in row_element:
            print(row_elemental)
#             if i==2:
#                 print(row_elemental)
#             else:
#                 i+=1
#         print(len(row_element))
#     print("*"*20)
# Out:
# Dutch
# Duits
# Deutsch
# <a data-music-file="cognates/Dutch.MP3" href="#">hear</a>
#  -
#
# <a data-music-file="Dutch2.MP3" href="#">2</a>
# The Dutch and German words mean 'German.'
# wife
# wijf
# Weib
# <a data-music-file="cognates/wife.MP3" href="#">hear</a>
# Dutch and German: (insulting) 'woman'
#
# <tt>(Do not use.)</tt>
# life
# lijf
# Leib
# <a data-music-file="cognates/life.MP3" href="#">hear</a>
# Dutch and German: '(human) body.'
# thumb
# duim
# Daumen
# <a data-music-file="cognates/thumb.MP3" href="#">hear</a>
# thunder
# donder
# Donner
# <a data-music-file="cognates/thunder.MP3" href="#">hear</a>
# craft
# kracht
# Kraft
# <a data-music-file="cognates/craft.MP3" href="#">hear</a>
# Dutch and German: power
# soft
# zacht
# sanft
# <a data-music-file="cognates/soft.MP3" href="#">hear</a>
# to wait
# wachten
# warten
# <a data-music-file="cognates/towait.MP3" href="#">hear</a>
# to sigh
# zuchten
# seufzen
# <a data-music-file="cognates/tosigh.MP3" href="#">hear</a>
# ...
